# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree

# %%
iris = load_iris()

X = iris.data
y = iris.target

print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42
)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

# %%
accuracy_knn = accuracy_score(y_test, y_pred_knn)

print("Precisión K-NN:", accuracy_knn)
# Out:
# Precisión K-NN: 1.0

# %%
tree_model = DecisionTreeClassifier(max_depth=3)

tree_model.fit(X_train, y_train)

y_pred_tree = tree_model.predict(X_test)

# %%
accuracy_tree = accuracy_score(y_test, y_pred_tree)

print("Precisión Árbol de Decisión:", accuracy_tree)
# Out:
# Precisión Árbol de Decisión: 1.0

# %%
plt.figure(figsize=(10,8))

plot_tree(
    tree_model,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    filled=True
)

plt.show()

# %%
print("Resultado final:")
print("-------------------")
print("K-NN:", accuracy_knn)
print("Árbol de Decisión:", accuracy_tree)
# Out:
# Resultado final:
# -------------------
# K-NN: 1.0
# Árbol de Decisión: 1.0

# %%
print("""
Conclusión:

En esta actividad se utilizaron los algoritmos K-NN y Árbol de Decisión
para clasificar las flores del dataset Iris.

Ambos modelos lograron una precisión alta, aunque el Árbol de Decisión
permitió visualizar de forma más clara cómo se toman las decisiones
según las características de las flores.

K-NN resultó sencillo de implementar y obtuvo buenos resultados,
mientras que el Árbol de Decisión fue más fácil de interpretar visualmente.
""")
# Out:
# Conclusión:
#
# En esta actividad se utilizaron los algoritmos K-NN y Árbol de Decisión
# para clasificar las flores del dataset Iris.
#
# Ambos modelos lograron una precisión alta, aunque el Árbol de Decisión
# permitió visualizar de forma más clara cómo se toman las decisiones
# según las características de las flores.
#
# K-NN resultó sencillo de implementar y obtuvo buenos resultados,
# mientras que el Árbol de Decisión fue más fácil de interpretar visualmente.

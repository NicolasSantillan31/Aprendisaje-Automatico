# %% [markdown]
# # Semana 1 - NumPy

# %%
import numpy as np

# %% [markdown]
# Ejercicio 1

# %%
print(np.zeros(10))

# %% [markdown]
# Ejercicio 2

# %%
print(np.arange(1,21))

# %% [markdown]
# Ejercicio 3

# %%
print(np.arange(2,51,2))

# %% [markdown]
# Ejercicio 4

# %%
print(np.arange(10,0,-1))

# %% [markdown]
# Ejercicio 5

# %%
print(np.random.rand(4,4))

# %% [markdown]
# Ejercicio 6

# %%
a=np.array([1,2,3]); b=np.array([4,5,6]); print(a+b)

# %% [markdown]
# Ejercicio 7

# %%
m1=np.random.randint(1,11,(3,3)); m2=np.random.randint(1,11,(3,3)); print(np.dot(m1,m2))

# %% [markdown]
# Ejercicio 8

# %%
arr=np.random.randint(1,101,15); print(arr, np.max(arr), np.min(arr), np.mean(arr))

# %% [markdown]
# Ejercicio 9

# %%
m=np.arange(1,26).reshape(5,5); print(np.diag(m))

# %% [markdown]
# Ejercicio 10

# %%
m=np.random.randint(1,21,(5,5)); print(m.sum(axis=1), m.sum(axis=0))

# %% [markdown]
# Reflexión:
# Trabajo con NumPy permitió comprender manejo de arrays y matrices para análisis de datos.
